# %%
from ase.io import write, read
from ase.visualize import view
from ase.build import bulk
from ase.build import surface

# %%
Pt = read("Pt.cif")
view(Pt)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 Pt = read("Pt.cif")
#       2 view(Pt)
#
# File ~/anaconda3/envs/crystals/lib/python3.11/site-packages/ase/io/formats.py:729, in read(filename, index, format, parallel, do_not_split_by_at_sign, **kwargs)
#     727 if index is None:
#     728     index = -1
# --> 729 format = format or filetype(filename, read=isinstance(filename, str))
#     731 io = get_ioformat(format)
#     732 if isinstance(index, (slice, str)):
#
# File ~/anaconda3/envs/crystals/lib/python3.11/site-packages/ase/io/formats.py:920, in filetype(filename, read, guess)
#     917     return ext
#     919 if orig_filename == filename:
# --> 920     fd = open_with_compression(filename, 'rb')
#     921 else:
#     922     fd = orig_filename  # type: ignore
#
# File ~/anaconda3/envs/crystals/lib/python3.11/site-packages/ase/io/formats.py:551, in open_with_compression(filename, mode)
#     548     return lzma.open(filename, mode)
#     549 else:
#     550     # Either None or unknown string
# --> 551     return open(filename, mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Pt.cif'
